# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
import math as m

# %%
#defining entropy function for decision  tree
def entropy(y):
    set_val = set(y)
    total = len(y)
    single_entropy = 0
    for l in set_val:
        p = (y == l).sum() / total
        single_entropy += -p*m.log2(p)
    return single_entropy

# %%
# calculating information gain for decsion tree
def info_gain_modified(x , y , index):
    
    #taking out unique vals in y so as to calculate initial info_gain
    vals = set(y)
    info_orig = 0
    
    #calculating original info gain of parent node
    for f in vals :
        temp = y.loc[y == f]
        info_orig += (-1*len(temp)/len(y))*entropy(temp)
        
    #IN THE CODE , WE ARE BASICALLY TRYING TO IDENTIFY THE BEST FEATURE AMONGST MEAN VALUES , RATHER THAN TAKING OUT AVERAGE FOR 
    # ALL DATA.
    
    step = x[x.columns[index]].mean()
    init = step/2
    condition = 0
    maxm = -1e100
    split_info_max = -1e100
    
    # RUNNING LOOP FROM 0 TO MAX VALUE.
    while init <= 2*step :
        final_entropy = 0
        y_new_greater  = y.loc[x[x.columns[index]] >= init]
        y_new_less  = y.loc[x[x.columns[index]] < init]
        
        ######################################################## CALCULATING COEFF FOR INFO_GAIN.
        d1 = len(y_new_greater)
        d2 = len(y_new_less)
        d = d1 + d2
        D1 = float(-1*d1)/d
        D2 = float(-1*d2)/d
        #########################################################
        
        #INFORMATION REQUIRED CALCULATED :
        final_entropy = float(D1*(entropy(y_new_greater))) + float(D2*(entropy(y_new_less)))
        if final_entropy > maxm:
            maxm = final_entropy
            condition = init
            split_info_max = split_info(y_new_greater , y_new_less) 
        init += init
    #RETURING INFORMATION GAIN , CONDITION FOR SPLITTING , AND SPLIT INFO FOR OPTIMAL SPLIT.    
    return info_orig  - maxm, condition , split_info_max

# %%
#CALCULATING SPLIT INFO FOR A CLASS
def split_info(y1 , y2) :
    d1 = len(y1)
    d2 = len(y2)
    d = d1 + d2
    if(d1 == 0 or d2 == 0 or d == 0):
        return 0
    p = (-1*d1*m.log2(d1/d))/d +  (-1*d2*m.log2(d2/d))/d
    return p

# %%
#CALCULATING GAIN RATIO
def gain_ratio(x ,y ,index):
    return info_gain_modified(x , y , index)[0] / info_gain_modified(x , y , index)[2]

# %%
def dt_modified(x , y , feature_index , level):
    
    #SHOWS HOW MANY MORE FEATURES ARE LEFT TO SPLIT UPON
    print('-------------------------------------------------------------------------------------------')
    print('features list left to split upon : ' , feature_index)
    
    #BASE CASE : pure node : return
    if(len(set(y)) == 1): 
        print('Level : ' , level)
        print('Current entropy : ' , 0.0)
        print('count of feature :' , len(y))
        print('Reached leaf node')
        print('-------------------------------------------------------------------------------------------')
        print()
        return
    
    #BASE CASE : all features are exhausted
    if(len(feature_index) == 0):
        print('Level : ' , level)
        print('Current entropy : ' , entropy(y))
        print('number of features : ' , len(y))
        print('leaf node reached , no features left')
        print('-------------------------------------------------------------------------------------------')
        print()
        return
    
    ################################################################################
    maxm = -10000000
    best_feature = -1
    condition = 0
    for i in feature_index:
        gain = gain_ratio(x , y , i)
        if gain > maxm:
            maxm = gain
            best_feature = i
            condition = info_gain_modified(x , y , i)[1]
            
    # printing required data:
    
    print('Level : ' , level)
    print('Current entropy : ' , entropy(y))
    print('Splitting on feature' , x.columns[best_feature] , 'on criteria that data is centered: ' , condition  
          , 'with gain ratio : ' , maxm)
    print('num_features :' , len(y))
    
    # finding all classes to split upon
    labels = set(x[x.columns[best_feature]])
    
    #removing the used feature
    if best_feature not in feature_index:
        return
    feature_index.remove(best_feature)
    
    x_new_greater  = x.loc[x[x.columns[best_feature]] >= condition]
    y_new_greater  = y.loc[x[x.columns[best_feature]] >=  condition]
    x_new_lesser  = x.loc[x[x.columns[best_feature]] < condition]
    y_new_lesser  = y.loc[x[x.columns[best_feature]] <  condition]
    
    print('Number of features which are > ' , condition , ' : ' , len(y_new_greater))
    print('Number of features which are < ' ,   condition , ' : ' , len(y_new_lesser))
    print('-------------------------------------------------------------------------------------------')
    print()
    
    #recursively calling DT to print features
    dt_modified(x_new_greater , y_new_greater , feature_index , level + 1)
    dt_modified(x_new_lesser , y_new_lesser , feature_index , level + 1)
    feature_index.append(best_feature)

# %%
# So basically now I have two implementatios of my decision tree based using myfunctions.
# The first one uses your given split dataset and is somehwta less accurate
# The second one uses the original iris dataset and hence gives us a better result as it uses original integer values from the dataset.

# %%
# First Implementation:
from sklearn import datasets
import pandas as pd

# %%
iris = datasets.load_iris()

# %%
df = pd.DataFrame(iris.data)
df.columns = ["sl", "sw", 'pl', 'pw']

# %%
#Function to find label for a value
#if MIN_Value <=val < (m + Mean_Value) / 2 then it is assigned label a
#if (m + Mean_Value) <=val < Mean_Value then it is assigned label b
#if (Mean_Value) <=val < (Mean_Value + MAX_Value)/2 then it is assigned label c
#if (Mean_Value + MAX_Value)/2 <=val <= MAX_Value  then it is assigned label d

def label(val, *boundaries):
    if (val < boundaries[0]):
        return 1
    elif (val < boundaries[1]):
        return 2
    elif (val < boundaries[2]):
        return 3
    else:
        return 4

#Function to convert a continuous data into labelled data
#There are 4 lables  - a, b, c, d
def toLabel(df, old_feature_name):
    second = df[old_feature_name].mean()
    minimum = df[old_feature_name].min()
    first = (minimum + second)/2
    maximum = df[old_feature_name].max()
    third = (maximum + second)/2
    return df[old_feature_name].apply(label, args= (first, second, third))

# %%
#Convert all columns to labelled data
df['sl'] = toLabel(df, 'sl')
df['sw'] = toLabel(df, 'sw')
df['pl'] = toLabel(df, 'pl')
df['pw'] = toLabel(df, 'pw')
df
# Out:
#      sl  sw  pl  pw
# 0     2   3   1   1
# 1     1   2   1   1
# 2     1   3   1   1
# 3     1   3   1   1
# 4     1   3   1   1
# 5     2   4   1   1
# 6     1   3   1   1
# 7     1   3   1   1
# 8     1   2   1   1
# 9     1   3   1   1
# 10    2   3   1   1
# 11    1   3   1   1
# 12    1   2   1   1
# 13    1   2   1   1
# 14    2   4   1   1
# 15    2   4   1   1
# 16    2   4   1   1
# 17    2   3   1   1
# 18    2   4   1   1
# 19    2   4   1   1
# 20    2   3   1   1
# 21    2   3   1   1
# 22    1   3   1   1
# 23    2   3   1   1
# 24    1   3   1   1
# 25    1   2   1   1
# 26    1   3   1   1
# 27    2   3   1   1
# 28    2   3   1   1
# 29    1   3   1   1
# ..   ..  ..  ..  ..
# 120   4   3   4   4
# 121   2   2   3   4
# 122   4   2   4   4
# 123   3   2   3   3
# 124   3   3   4   4
# 125   4   3   4   3
# 126   3   2   3   3
# 127   3   2   3   3
# 128   3   2   4   4
# 129   4   2   4   3
# 130   4   2   4   4
# 131   4   4   4   4
# 132   3   2   4   4
# 133   3   2   3   3
# 134   3   2   4   3
# 135   4   2   4   4
# 136   3   3   4   4
# 137   3   3   4   3
# 138   3   2   3   3
# 139   4   3   4   4
# 140   3   3   4   4
# 141   4   3   3   4
# 142   2   2   3   4
# 143   3   3   4   4
# 144   3   3   4   4
# 145   3   2   3   4
# 146   3   1   3   4
# 147   3   2   3   4
# 148   3   3   4   4
# 149   3   2   3   3
#
# [150 rows x 4 columns]

# %%
x_train , x_test = train_test_split(df.iloc[: , 0:] , random_state = 20)
y_train , y_test = train_test_split(df.iloc[: , -1] , random_state = 20)
list_of_features = x_train.columns.tolist()

# %%
feature_idx = [i for i in range(len(x_train.columns))]
feature_idx
# Out:
# [0, 1, 2, 3]

# %%
#CALLING THE DECISION TREE FUNCTION TO PRINT THE REQUIRED TREE
feature_idx = [i for i in range(len(x_train.columns))]
dt_modified(x_train , y_train , feature_idx , 0)
# Out:
# -------------------------------------------------------------------------------------------
# features list left to split upon :  [0, 1, 2, 3]
# Level :  0
# Current entropy :  1.785800617340724
# Splitting on feature sw on criteria that data is centered:  2.4910714285714284 with gain ratio :  1.4847983020894693
# num_features : 112
# Number of features which are >  2.4910714285714284  :  55
# Number of features which are <  2.4910714285714284  :  57
# -------------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------------
# features list left to split upon :  [0, 2, 3]
# Level :  1
# Current entropy :  1.3492147162949246
# Splitting on feature sl on criteria that data is centered:  2.2545454545454544 with gain ratio :  0.38958122483328506
# num_features : 55
# Number of features which are >  2.2545454545454544  :  22
# Number of features which are <  2.2545454545454544  :  33
# -------------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------------
# features list left to split upon :  [2, 3]
# Level :  2
# Current entropy :  0.9456603046006401
# Splitting on feature pl on criteria that data is centered:  3.590909090909091 with gain ratio :  0.7598866360979396
# num_features : 22
# Number of features which are >  3.590909090909091  :  13
# Number of features which are <  3.590909090909091  :  9
# -------------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------------
# features list left to split upon :  [3]
# Level :  3
# Current entropy :  0.6193821946787638
# Splitting on feature pw on criteria that data is centered:  3.8461538461538463 with gain ratio :  0.0
# num_features : 13
# Number of features which are >  3.8461538461538463  :  11
# Number of features which are <  3.8461538461538463  :  2
# -------------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------------
# features list left to split upon :  []
# Level :  4
# Current entropy :  0.0
# count of feature : 11
# Reached leaf node
# -------------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------------
# features list left to split upon :  []
# Level :  4
# Current entropy :  0.0
# count of feature : 2
# Reached leaf node
# -------------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------------
# features list left to split upon :  [3]
# Level :  3
# Current entropy :  0.9182958340544896
# Splitting on feature pw on criteria that data is centered:  3.3333333333333335 with gain ratio :  0.0
# num_features : 9
# Number of features which are >  3.3333333333333335  :  3
# Number of features which are <  3.3333333333333335  :  6
# -------------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------------
# features list left to split upon :  []
# Level :  4
# Current entropy :  0.0
# count of feature : 3
# Reached leaf node
# -------------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------------
# features list left to split upon :  []
# Level :  4
# Current entropy :  0.0
# count of feature : 6
# Reached leaf node
# -------------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------------
# features list left to split upon :  [3, 2]
# Level :  2
# Current entropy :  0.0
# count of feature : 33
# Reached leaf node
# -------------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------------
# features list left to split upon :  [3, 2, 0]
# Level :  1
# Current entropy :  1.6149534459617556
# Splitting on feature pl on criteria that data is centered:  1.4824561403508771 with gain ratio :  2.766119756238432
# num_features : 57
# Number of features which are >  1.4824561403508771  :  52
# Number of features which are <  1.4824561403508771  :  5
# -------------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------------
# features list left to split upon :  [3, 0]
# Level :  2
# Current entropy :  1.3001946428885267
# Splitting on feature sl on criteria that data is centered:  1.3365384615384615 with gain ratio :  4.978705028319635
# num_features : 52
# Number of features which are >  1.3365384615384615  :  50
# Number of features which are <  1.3365384615384615  :  2
# -------------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------------
# features list left to split upon :  [3]
# Level :  3
# Current entropy :  1.2177968115985955
# Splitting on feature pw on criteria that data is centered:  3.2 with gain ratio :  0.4235731576444572
# num_features : 50
# Number of features which are >  3.2  :  14
# Number of features which are <  3.2  :  36
# -------------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------------
# features list left to split upon :  []
# Level :  4
# Current entropy :  0.0
# count of feature : 14
# Reached leaf node
# -------------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------------
# features list left to split upon :  []
# Level :  4
# Current entropy :  0.5032583347756457
# number of features :  36
# leaf node reached , no features left
# -------------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------------
# features list left to split upon :  [3]
# Level :  3
# Current entropy :  0.0
# count of feature : 2
# Reached leaf node
# -------------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------------
# features list left to split upon :  [3, 0]
# Level :  2
# Current entropy :  0.0
# count of feature : 5
# Reached leaf node
# -------------------------------------------------------------------------------------------

# %%
# Second Implementation:
iris = datasets.load_iris()

#  converting dataset to pandas DataFrame
df = pd.DataFrame(data= np.c_[iris['data'], iris['target']],columns= iris['feature_names'] + ['target'])
df.columns = ['sl' , 'sw' , 'pl' , 'pw' , 'target']

#  dataset splitting into train and test
x_train , x_test = train_test_split(df.iloc[: , 0:-1] , random_state = 20)
y_train , y_test = train_test_split(df.iloc[: , -1] , random_state = 20)
list_of_features = x_train.columns.tolist()

#testing some points :
#x_train[x_train.columns[1]]
#new = y_train.loc[x_train[x_train.columns[0]] == 6.4]

#taking out feature indices(column indices)
feature_idx = [i for i in range(len(x_train.columns))]
feature_idx
# Out:
# [0, 1, 2, 3]

# %%
#CALLING THE DECISION TREE FUNCTION TO PRINT THE REQUIRED TREE
feature_idx = [i for i in range(len(x_train.columns))]
dt_modified(x_train , y_train , feature_idx , 0)
# Out:
# -------------------------------------------------------------------------------------------
# features list left to split upon :  [0, 1, 2, 3]
# Level :  0
# Current entropy :  1.5844996446144277
# Splitting on feature sw on criteria that data is centered:  3.0928571428571416 with gain ratio :  1.3177216932877882
# num_features : 112
# Number of features which are >  3.0928571428571416  :  55
# Number of features which are <  3.0928571428571416  :  57
# -------------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------------
# features list left to split upon :  [0, 2, 3]
# Level :  1
# Current entropy :  1.3090909691036434
# Splitting on feature sl on criteria that data is centered:  5.74181818181818 with gain ratio :  0.4548646284299678
# num_features : 55
# Number of features which are >  5.74181818181818  :  23
# Number of features which are <  5.74181818181818  :  32
# -------------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------------
# features list left to split upon :  [2, 3]
# Level :  2
# Current entropy :  1.0666152167384504
# Splitting on feature pl on criteria that data is centered:  5.239130434782608 with gain ratio :  0.4961608761150104
# num_features : 23
# Number of features which are >  5.239130434782608  :  14
# Number of features which are <  5.239130434782608  :  9
# -------------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------------
# features list left to split upon :  [3]
# Level :  3
# Current entropy :  0.0
# count of feature : 14
# Reached leaf node
# -------------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------------
# features list left to split upon :  [3]
# Level :  3
# Current entropy :  1.224394445405986
# Splitting on feature pw on criteria that data is centered:  0.7666666666666667 with gain ratio :  1.432934262185295
# num_features : 9
# Number of features which are >  0.7666666666666667  :  8
# Number of features which are <  0.7666666666666667  :  1
# -------------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------------
# features list left to split upon :  []
# Level :  4
# Current entropy :  0.8112781244591328
# number of features :  8
# leaf node reached , no features left
# -------------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------------
# features list left to split upon :  []
# Level :  4
# Current entropy :  0.0
# count of feature : 1
# Reached leaf node
# -------------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------------
# features list left to split upon :  [3, 2]
# Level :  2
# Current entropy :  0.0
# count of feature : 32
# Reached leaf node
# -------------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------------
# features list left to split upon :  [3, 2, 0]
# Level :  1
# Current entropy :  1.3254539799066205
# Splitting on feature sl on criteria that data is centered:  5.991228070175439 with gain ratio :  1.104702989064482
# num_features : 57
# Number of features which are >  5.991228070175439  :  30
# Number of features which are <  5.991228070175439  :  27
# -------------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------------
# features list left to split upon :  [3, 2]
# Level :  2
# Current entropy :  0.9709505944546686
# Splitting on feature pl on criteria that data is centered:  5.166666666666667 with gain ratio :  0.5017090219115049
# num_features : 30
# Number of features which are >  5.166666666666667  :  13
# Number of features which are <  5.166666666666667  :  17
# -------------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------------
# features list left to split upon :  [3]
# Level :  3
# Current entropy :  0.0
# count of feature : 13
# Reached leaf node
# -------------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------------
# features list left to split upon :  [3]
# Level :  3
# Current entropy :  0.8739810481273578
# Splitting on feature pw on criteria that data is centered:  1.5294117647058822 with gain ratio :  0.36361377978113685
# num_features : 17
# Number of features which are >  1.5294117647058822  :  7
# Number of features which are <  1.5294117647058822  :  10
# -------------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------------
# features list left to split upon :  []
# Level :  4
# Current entropy :  0.863120568566631
# number of features :  7
# leaf node reached , no features left
# -------------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------------
# features list left to split upon :  []
# Level :  4
# Current entropy :  0.0
# count of feature : 10
# Reached leaf node
# -------------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------------
# features list left to split upon :  [3, 2]
# Level :  2
# Current entropy :  1.2486545206672304
# Splitting on feature pw on criteria that data is centered:  0.5833333333333333 with gain ratio :  0.8062676395656346
# num_features : 27
# Number of features which are >  0.5833333333333333  :  22
# Number of features which are <  0.5833333333333333  :  5
# -------------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------------
# features list left to split upon :  [2]
# Level :  3
# Current entropy :  0.6840384356390417
# Splitting on feature pl on criteria that data is centered:  4.1863636363636365 with gain ratio :  0.47283015230032005
# num_features : 22
# Number of features which are >  4.1863636363636365  :  11
# Number of features which are <  4.1863636363636365  :  11
# -------------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------------
# features list left to split upon :  []
# Level :  4
# Current entropy :  0.9456603046006401
# number of features :  11
# leaf node reached , no features left
# -------------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------------
# features list left to split upon :  []
# Level :  4
# Current entropy :  0.0
# count of feature : 11
# Reached leaf node
# -------------------------------------------------------------------------------------------
#
# -------------------------------------------------------------------------------------------
# features list left to split upon :  [2]
# Level :  3
# Current entropy :  0.0
# count of feature : 5
# Reached leaf node
# -------------------------------------------------------------------------------------------
